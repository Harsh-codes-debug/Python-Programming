# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\harsh\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\harsh\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\harsh\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harsh\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\harsh\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\harsh\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Data Structure in Pandas
#Series
#DataFrame

# %%
#Series
#A Series is a one-dimensional array containing a sequence of values of any data type (int, float, list,string, etc) which by default have numeric data labels starting from zero.

# %%
#Example of a series containing names of students is given below:
# Index Value
# 0     Arnab
# 1     Sahir
# 2     Ramit
# 3     Divyam
# 4     Kritika

# %%
# Creation of Series
import pandas as pd
series1 = pd.Series([10,20,30])#Create Series
print(series1)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
#Example has a numeric index in random order.
series2 = pd.Series(["Kavita","Shyam","Ravi"], index=[3,5,1])
print(series2)
# Out:
# 3    Kavita
# 5     Shyam
# 1      Ravi
# dtype: object

# %%
import numpy as np
import pandas as pd 
array1 = np.array([1,2,3,4])
series3 =pd.Series(array1)
print(series3)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int32

# %%
# we can use letters or strings as indices:
series4 = pd.Series(array1, index = ["Jan","Feb", "Mar", "Apr"])
print(series4)
# Out:
# Jan    1
# Feb    2
# Mar    3
# Apr    4
# dtype: int32

# %%
#Creation of Series from Dictionary
dict1 = {'India': 'NewDelhi', 'UK':'London','Japan':'Tokoyo'}
print(dict1)
# Out:
# {'India': 'NewDelhi', 'UK': 'London', 'Japan': 'Tokoyo'}

# %%
series8= pd.Series(dict1)
print(series8)
# Out:
# India    NewDelhi
# UK         London
# Japan      Tokoyo
# dtype: object

# %%
# Accessing Elements of a Series
import pandas as pd
seriesNum = pd.Series([10,20,30])
seriesNum
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
seriesMnths = pd.Series([2,3,4],index=["Feb","Mar","Apr"])
seriesMnths["Mar"]
# Out:
# 3

# %%
#Slicing
seriesCapCntry = pd.Series(['NewDelhi', 'WashingtonDC', 'London','Paris'], index=['India', 'USA', 'UK', 'France'])
seriesCapCntry
# Out:
# India         NewDelhi
# USA       WashingtonDC
# UK              London
# France           Paris
# dtype: object

# %%
seriesCapCntry[1:3]
# Out:
# USA    WashingtonDC
# UK           London
# dtype: object

# %%
# Accessing Elements of a Series
import pandas as pd
seriesNum = pd.Series([10,20,30])
seriesNum
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
seriesMnths = pd.Series([2,3,4],index=["Feb","Mar","Apr"])
seriesMnths["Mar"]
# Out:
# 3

# %%
seriesNum[2]
# Out:
# 30

# %%
#Slicing
seriesCapCntry = pd.Series(['NewDelhi', 'WashingtonDC', 'London','Paris'], index=['India', 'USA', 'UK', 'France'])
seriesCapCntry
# Out:
# India         NewDelhi
# USA       WashingtonDC
# UK              London
# France           Paris
# dtype: object

# %%
#Methods of Series
import numpy as np
seriesTenTwenty=pd.Series(np.arange(10,20, 1 ))
print(seriesTenTwenty)
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# 5    15
# 6    16
# 7    17
# 8    18
# 9    19
# dtype: int32

# %%
seriesTenTwenty.head(2)
# Out:
# 0    10
# 1    11
# dtype: int32

# %%
seriesTenTwenty.count()
# Out:
# 10

# %%
seriesTenTwenty.tail(2)
# Out:
# 8    18
# 9    19
# dtype: int32

# %%
# Mathematical Operations on Series
seriesA = pd.Series([1,2,3,4,5], index =['a', 'b', 'c', 'd', 'e'])
seriesA
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
seriesB = pd.Series([10,20,-10,-50,100],
index = ['z', 'y', 'a', 'c', 'e'])
seriesB
# Out:
# z     10
# y     20
# a    -10
# c    -50
# e    100
# dtype: int64

# %%
#that the output of addition is NaN if one of the elements or both elements have no value.
seriesA + seriesB
# Out:
# a     -9.0
# b      NaN
# c    -47.0
# d      NaN
# e    105.0
# y      NaN
# z      NaN
# dtype: float64

# %%
#Subtraction of two Series
seriesA - seriesB
# Out:
# a    11.0
# b     NaN
# c    53.0
# d     NaN
# e   -95.0
# y     NaN
# z     NaN
# dtype: float64

# %%
#Multiplication of two Series
seriesA * seriesB
# Out:
# a    -10.0
# b      NaN
# c   -150.0
# d      NaN
# e    500.0
# y      NaN
# z      NaN
# dtype: float64

# %%
#Multiplication of two Series
seriesA * seriesB
# Out:
# a    -10.0
# b      NaN
# c   -150.0
# d      NaN
# e    500.0
# y      NaN
# z      NaN
# dtype: float64

# %%
# Division of two Series
seriesA/seriesB
# Out:
# a   -0.10
# b     NaN
# c   -0.06
# d     NaN
# e    0.05
# y     NaN
# z     NaN
# dtype: float64

# %%
# DataFrame
# A DataFrame is a two-dimensional labelled data structure like a table of MySQL. It contains rows and columns, and therefore has both a row and column index. Each column can have a different type of value such as numeric, string, boolean, etc., as in tables of a database.

# %%
# Creation of DataFrame
# Creation of DataFrame from NumPy ndarrays
import numpy as np
array1 = np.array([10,20,30])
array2 = np.array([100,200,300])
array3 = np.array([-10,-20,-30, -40])
dFrame4 = pd.DataFrame(array1)
dFrame4
# Out:
#     0
# 0  10
# 1  20
# 2  30

# %%
#Creation of DataFrame from List of Dictionaries
listDict = [{'a':10, 'b':20}, {'a':5,'b':10, 'c':20}]
dFrameListDict = pd.DataFrame(listDict)
dFrameListDict
# Out:
#     a   b     c
# 0  10  20   NaN
# 1   5  10  20.0

# %%
#Creation of DataFrame from Series
seriesA = pd.Series([1,2,3,4,5],index = ['a', 'b', 'c', 'd', 'e'])
seriesB = pd.Series ([1000,2000,-1000,-5000,1000],index = ['a', 'b', 'c', 'd', 'e'])
seriesC = pd.Series([10,20,-10,-50,100],index = ['z', 'y', 'a', 'c', 'e'])

dFrame6 = pd.DataFrame(seriesA)
dFrame6
# Out:
#    0
# a  1
# b  2
# c  3
# d  4
# e  5

# %%
dFrame7 = pd.DataFrame([seriesA, seriesB])
dFrame7
# Out:
#       a     b     c     d     e
# 0     1     2     3     4     5
# 1  1000  2000 -1000 -5000  1000

# %%
# Creation of DataFrame from Dictionary of Series
ResultSheet={'Arnab': pd.Series([90, 91, 97],index=['Maths','Science','Hindi']),
'Ramit': pd.Series([92, 81, 96],index=['Maths','Science','Hindi']),
'Sahir': pd.Series([89, 91, 88],index=['Maths','Science','Hindi']),
'Riya': pd.Series([81, 71, 67],index=['Maths','Science','Hindi']),
'Mallika': pd.Series([94, 95, 99],index=['Maths','Science','Hindi'])}
ResultDF = pd.DataFrame(ResultSheet)
ResultDF
# Out:
#          Arnab  Ramit  Sahir  Riya  Mallika
# Maths       90     92     89    81       94
# Science     91     81     91    71       95
# Hindi       97     96     88    67       99

# %%
#Operations on rows and columns in DataFrames
#Adding a New Column to a DataFrame
ResultDF['Jimmy']=[89,78,76]
ResultDF
# Out:
#          Arnab  Ramit  Sahir  Riya  Mallika  Jimmy
# Maths       90     92     89    81       94     89
# Science     91     81     91    71       95     78
# Hindi       97     96     88    67       99     76

# %%
#Adding a New Row to a DataFrame
#DataFRame.loc[] method can also be used to change the data values of a row to a particular value
ResultDF.loc['English']=  [85,86,83,80,9089,82]
ResultDF
# Out:
#          Arnab  Ramit  Sahir  Riya  Mallika  Jimmy
# Maths       90     92     89    81       94     89
# Science     91     81     91    71       95     78
# Hindi       97     96     88    67       99     76
# English     85     86     83    80     9089     82

# %%
#Deleting Rows or Columns from a DataFrame
#delete the row with label 'Science'
ResultDF = ResultDF.drop('Science', axis=0)
ResultDF
# Out:
#          Arnab  Ramit  Sahir  Riya  Mallika  Jimmy
# Maths       90     92     89    81       94     89
# Hindi       97     96     88    67       99     76
# English     85     86     83    80     9089     82

# %%
#Delete the columns having labels  'Ramit' and 'Riya':
ResultDF = ResultDF.drop(['Ramit','Riya'], axis=1)
ResultDF
# Out:
#          Arnab  Sahir  Mallika  Jimmy
# Maths       90     89       94     89
# Hindi       97     88       99     76
# English     85     83     9089     82

# %%
#Renaming Row Labels of a DataFrame
#To rename the row indices Maths to sub1, Science to sub2, Hindi to sub3 and English to sub4 we can write the following statement:
ResultDF=ResultDF.rename({'Maths':'Sub1','English':'Sub3','Hindi':'Sub4'}, axis='index')
print(ResultDF)
# Out:
#       Arnab  Sahir  Mallika  Jimmy
# Sub1     90     89       94     89
# Sub4     97     88       99     76
# Sub3     85     83     9089     82

# %%
#Accessing DataFrames Element through Indexing
#Label Based Indexing
ResultDF.loc['Sub3']
# Out:
# Arnab        85
# Sahir        83
# Mallika    9089
# Jimmy        82
# Name: Sub3, dtype: int64

# %%
ResultDF.loc['Sub1': 'Sub4']
# Out:
#       Arnab  Sahir  Mallika  Jimmy
# Sub1     90     89       94     89
# Sub4     97     88       99     76

# %%
import pandas as pd 
df=pd.read_csv("D:\\AAFT College Data\\Python Programming\\Classs_Python-Programming\\Mall_Customers.csv")
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
print(df.head(10))
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %%
print(df.tail())
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None

# %%
import pandas as pd 
df=pd.read_csv("C:\\Users\\harsh\\Downloads\\iris.data.csv")
df
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   5.1          149 non-null    float64
#  1   3.5          149 non-null    float64
#  2   1.4          149 non-null    float64
#  3   0.2          149 non-null    float64
#  4   Iris-setosa  149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df.head(10)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa
# 7  4.4  2.9  1.4  0.2  Iris-setosa
# 8  4.9  3.1  1.5  0.1  Iris-setosa
# 9  5.4  3.7  1.5  0.2  Iris-setosa

# %%
df.describe()
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.chart()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10840\266646220.py in ?()
# ----> 1 df.chart()
#
# c:\Users\harsh\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'chart'

# %%
import  matplotlib.pyplot as pt

# %%
df.plot()
# Out:
# <Axes: >

# %%
df=pd.read_csv("D:\\AAFT College Data\\Python Programming\\Datasets\\Superstone.csv" ,encoding="Latin1")
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
(df['Sub-Category'].value_counts()).sort_values()
# Out:
# Sub-Category
# Copiers          68
# Machines        115
# Supplies        190
# Fasteners       217
# Bookcases       228
# Envelopes       254
# Tables          319
# Labels          364
# Appliances      466
# Chairs          617
# Accessories     775
# Art             796
# Storage         846
# Phones          889
# Furnishings     957
# Paper          1370
# Binders        1523
# Name: count, dtype: int64

# %%
(df['Sub-Category'].value_counts()).sort_values(ascending=False)
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
df.sort_values('Category')
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 8133    8134  CA-2015-131352   10/8/2015  10/13/2015  Standard Class
# 1903    1904  CA-2017-167094  10/21/2017  10/22/2017     First Class
# 6151    6152  CA-2014-111871   3/18/2014   3/21/2014    Second Class
# 6153    6154  CA-2017-151484   4/20/2017   4/23/2017     First Class
# ...      ...             ...         ...         ...             ...
# 1844    1845  US-2017-113852   7/29/2017    8/2/2017  Standard Class
# 3921    3922  CA-2016-110044   6/28/2016    7/2/2016    Second Class
# 6173    6174  US-2014-106299    8/2/2014    8/8/2014  Standard Class
# 8348    8349  US-2015-115238   4/30/2015    5/4/2015  Standard Class
# 2522    2523  CA-2016-124352  10/15/2016  10/21/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# 0       CG-12520       Claire Gute     Consumer  United States      Henderson
# 8133    GH-14485         Gene Hale    Corporate  United States         Dallas
# 1903    DK-12835   Damala Kotsonis    Corporate  United States    Springfield
# 6151    EK-13795     Eileen Kiefer  Home Office  United States  San Francisco
# 6153    CV-12805     Cynthia Voltz    Corporate  United States   Philadelphia
# ...          ...               ...          ...            ...            ...
# 1844    GW-14605  Giulietta Weimer     Consumer  United States        Seattle
# 3921    RF-19735      Roland Fjeld     Consumer  United States        Chicago
# 6173    NZ-18565     Nick Zandusky  Home Office  United States    Springfield
# 8348    JW-15220         Jane Waco    Corporate  United States       Lawrence
# 2522    CD-12790   Cynthia Delaney  Home Office  United States  Oklahoma City
#
#       ... Postal Code   Region       Product ID    Category Sub-Category  \
# 0     ...       42420    South  FUR-BO-10001798   Furniture    Bookcases
# 8133  ...       75081  Central  FUR-FU-10003708   Furniture  Furnishings
# 1903  ...       97477     West  FUR-CH-10000155   Furniture       Chairs
# 6151  ...       94110     West  FUR-BO-10004218   Furniture    Bookcases
# 6153  ...       19120     East  FUR-FU-10001876   Furniture  Furnishings
# ...   ...         ...      ...              ...         ...          ...
# 1844  ...       98115     West  TEC-AC-10003027  Technology  Accessories
# 3921  ...       60610  Central  TEC-PH-10001299  Technology       Phones
# 6173  ...       65807  Central  TEC-AC-10003237  Technology  Accessories
# 8348  ...        1841     East  TEC-PH-10001300  Technology       Phones
# 2522  ...       73120  Central  TEC-PH-10003442  Technology       Phones
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase   261.960         2
# 8133  Tenex Traditional Chairmats for Medium Pile Ca...    72.780         3
# 1903                Global Comet Stacking Armless Chair   478.480         2
# 6151  Bush Heritage Pine Collection 5-Shelf Bookcase...  1198.330        10
# 6153                          Computer Room Manger, 14"    51.968         2
# ...                                                 ...       ...       ...
# 1844   Imation 8GB Mini TravelDrive USB 2.0 Flash Drive    90.570         3
# 3921         Polycom CX300 Desktop Phone USB VoIP phone   359.976         3
# 6173                    Memorex Micro Travel Drive 4 GB    21.200         2
# 8348  iKross Bluetooth Portable Keyboard + Cell Phon...   209.500        10
# 2522      Samsung Replacement EH64AVFWE Premium Headset     5.500         1
#
#       Discount   Profit
# 0         0.00  41.9136
# 8133      0.60 -70.9605
# 1903      0.20  47.8480
# 6151      0.15  70.4900
# 6153      0.20  10.3936
# ...        ...      ...
# 1844      0.00  11.7741
# 3921      0.20  35.9976
# 6173      0.00   9.1160
# 8348      0.00  58.6600
# 2522      0.00   1.3750
#
# [9994 rows x 21 columns]

# %%
df.sort_values(['Category','Profit'])
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9639    9640  CA-2015-116638   1/28/2015   1/31/2015    Second Class
# 27        28  US-2015-150630   9/17/2015   9/21/2015  Standard Class
# 5320    5321  US-2017-162558   10/2/2017   10/5/2017     First Class
# 8993    8994  CA-2017-159100  10/16/2017  10/21/2017  Standard Class
# 463      464  CA-2016-109869   4/22/2016   4/29/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 8488    8489  CA-2016-158841    2/2/2016    2/4/2016    Second Class
# 2623    2624  CA-2017-127180  10/22/2017  10/24/2017     First Class
# 4190    4191  CA-2017-166709  11/17/2017  11/22/2017  Standard Class
# 8153    8154  CA-2017-140151   3/23/2017   3/25/2017     First Class
# 6826    6827  CA-2016-118689   10/2/2016   10/9/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# 9639    JH-15985       Joseph Holt     Consumer  United States        Concord
# 27      TB-21520   Tracy Blumstein     Consumer  United States   Philadelphia
# 5320    Dp-13240       Dean percer  Home Office  United States      Knoxville
# 8993    VP-21760  Victoria Pisteka    Corporate  United States       Columbia
# 463     TN-21040     Tanja Norvell  Home Office  United States        Phoenix
# ...          ...               ...          ...            ...            ...
# 8488    SE-20110      Sanjit Engle     Consumer  United States      Arlington
# 2623    TA-21385      Tom Ashbrook  Home Office  United States  New York City
# 4190    HL-15040      Hunter Lopez     Consumer  United States         Newark
# 8153    RB-19360      Raymond Buch     Consumer  United States        Seattle
# 6826    TC-20980      Tamara Chand    Corporate  United States      Lafayette
#
#       ... Postal Code   Region       Product ID    Category Sub-Category  \
# 9639  ...       28027    South  FUR-TA-10000198   Furniture       Tables
# 27    ...       19140     East  FUR-BO-10004834   Furniture    Bookcases
# 5320  ...       37918    South  FUR-TA-10000198   Furniture       Tables
# 8993  ...       38401    South  FUR-TA-10001950   Furniture       Tables
# 463   ...       85023     West  FUR-TA-10001889   Furniture       Tables
# ...   ...         ...      ...              ...         ...          ...
# 8488  ...       22204    South  TEC-MA-10001127  Technology     Machines
# 2623  ...       10024     East  TEC-CO-10004722  Technology      Copiers
# 4190  ...       19711     East  TEC-CO-10004722  Technology      Copiers
# 8153  ...       98115     West  TEC-CO-10004722  Technology      Copiers
# 6826  ...       47905  Central  TEC-CO-10004722  Technology      Copiers
#
#                                            Product Name      Sales  Quantity  \
# 9639  Chromcraft Bull-Nose Wood Oval Conference Tabl...   4297.644        13
# 27    Riverside Palais Royal Lawyers Bookcase, Royal...   3083.430         7
# 5320  Chromcraft Bull-Nose Wood Oval Conference Tabl...   2314.116         7
# 8993                       Balt Solid Wood Round Tables   1875.258         7
# 463   Bush Advantage Collection Racetrack Conference...   1272.630         6
# ...                                                 ...        ...       ...
# 8488  HP Designjet T520 Inkjet Large Format Printer ...   8749.950         5
# 2623              Canon imageCLASS 2200 Advanced Copier  11199.968         4
# 4190              Canon imageCLASS 2200 Advanced Copier  10499.970         3
# 8153              Canon imageCLASS 2200 Advanced Copier  13999.960         4
# 6826              Canon imageCLASS 2200 Advanced Copier  17499.950         5
#
#       Discount     Profit
# 9639       0.4 -1862.3124
# 27         0.5 -1665.0522
# 5320       0.4 -1002.7836
# 8993       0.4  -968.8833
# 463        0.5  -814.4832
# ...        ...        ...
# 8488       0.0  2799.9840
# 2623       0.2  3919.9888
# 4190       0.0  5039.9856
# 8153       0.0  6719.9808
# 6826       0.0  8399.9760
#
# [9994 rows x 21 columns]

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.drop_duplicates(subset=['Sub-Category'])
# Out:
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0         1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1         2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2         3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3         4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4         5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 5         6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 6         7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 7         8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 8         9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 9        10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 12       13  CA-2017-114412   4/15/2017   4/20/2017  Standard Class
# 26       27  CA-2016-121755   1/16/2016   1/20/2016    Second Class
# 30       31  US-2015-150630   9/17/2015   9/21/2015  Standard Class
# 53       54  CA-2016-105816  12/11/2016  12/17/2016  Standard Class
# 138     139  CA-2016-145583  10/13/2016  10/19/2016  Standard Class
# 165     166  CA-2014-139892    9/8/2014   9/12/2014  Standard Class
# 335     336  CA-2015-137946    9/1/2015    9/4/2015    Second Class
#
#     Customer ID    Customer Name    Segment        Country             City  \
# 0      CG-12520      Claire Gute   Consumer  United States        Henderson
# 1      CG-12520      Claire Gute   Consumer  United States        Henderson
# 2      DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 3      SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4      SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5      BH-11710  Brosina Hoffman   Consumer  United States      Los Angeles
# 6      BH-11710  Brosina Hoffman   Consumer  United States      Los Angeles
# 7      BH-11710  Brosina Hoffman   Consumer  United States      Los Angeles
# 8      BH-11710  Brosina Hoffman   Consumer  United States      Los Angeles
# 9      BH-11710  Brosina Hoffman   Consumer  United States      Los Angeles
# 12     AA-10480     Andrew Allen   Consumer  United States          Concord
# 26     EH-13945    Eric Hoffmann   Consumer  United States      Los Angeles
# 30     TB-21520  Tracy Blumstein   Consumer  United States     Philadelphia
# 53     JM-15265   Janet Molinari  Corporate  United States    New York City
# 138    LC-16885   Lena Creighton   Consumer  United States        Roseville
# 165    BM-11140     Becky Martin   Consumer  United States      San Antonio
# 335    DB-13615    Doug Bickford   Consumer  United States      Los Angeles
#
#      ... Postal Code   Region       Product ID         Category Sub-Category  \
# 0    ...       42420    South  FUR-BO-10001798        Furniture    Bookcases
# 1    ...       42420    South  FUR-CH-10000454        Furniture       Chairs
# 2    ...       90036     West  OFF-LA-10000240  Office Supplies       Labels
# 3    ...       33311    South  FUR-TA-10000577        Furniture       Tables
# 4    ...       33311    South  OFF-ST-10000760  Office Supplies      Storage
# 5    ...       90032     West  FUR-FU-10001487        Furniture  Furnishings
# 6    ...       90032     West  OFF-AR-10002833  Office Supplies          Art
# 7    ...       90032     West  TEC-PH-10002275       Technology       Phones
# 8    ...       90032     West  OFF-BI-10003910  Office Supplies      Binders
# 9    ...       90032     West  OFF-AP-10002892  Office Supplies   Appliances
# 12   ...       28027    South  OFF-PA-10002365  Office Supplies        Paper
# 26   ...       90049     West  TEC-AC-10003027       Technology  Accessories
# 30   ...       19140     East  OFF-EN-10001509  Office Supplies    Envelopes
# 53   ...       10024     East  OFF-FA-10000304  Office Supplies    Fasteners
# 138  ...       95661     West  OFF-SU-10001218  Office Supplies     Supplies
# 165  ...       78207  Central  TEC-MA-10000822       Technology     Machines
# 335  ...       90045     West  TEC-CO-10001449       Technology      Copiers
#
#                                           Product Name      Sales  Quantity  \
# 0                    Bush Somerset Collection Bookcase   261.9600         2
# 1    Hon Deluxe Fabric Upholstered Stacking Chairs,...   731.9400         3
# 2    Self-Adhesive Address Labels for Typewriters b...    14.6200         2
# 3        Bretford CR4500 Series Slim Rectangular Table   957.5775         5
# 4                       Eldon Fold 'N Roll Cart System    22.3680         2
# 5    Eldon Expressions Wood and Plastic Desk Access...    48.8600         7
# 6                                           Newell 322     7.2800         4
# 7                       Mitel 5320 IP Phone VoIP phone   907.1520         6
# 8    DXL Angle-View Binders with Locking Rings by S...    18.5040         3
# 9                     Belkin F5C206VTEL 6 Outlet Surge   114.9000         5
# 12                                          Xerox 1967    15.5520         3
# 26    Imation 8GB Mini TravelDrive USB 2.0 Flash Drive    90.5700         3
# 30                           Poly String Tie Envelopes     3.2640         2
# 53                                  Advantus Push Pins    15.2600         7
# 138                          Fiskars Softgrip Scissors    65.8800         6
# 165          Lexmark MX611dhe Monochrome Laser Printer  8159.9520         8
# 335               Hewlett Packard LaserJet 3310 Copier   959.9840         2
#
#      Discount     Profit
# 0        0.00    41.9136
# 1        0.00   219.5820
# 2        0.00     6.8714
# 3        0.45  -383.0310
# 4        0.20     2.5164
# 5        0.00    14.1694
# 6        0.00     1.9656
# 7        0.20    90.7152
# 8        0.20     5.7825
# 9        0.00    34.4700
# 12       0.20     5.4432
# 26       0.00    11.7741
# 30       0.20     1.1016
# 53       0.00     6.2566
# 138      0.00    18.4464
# 165      0.40 -1359.9920
# 335      0.20   335.9944
#
# [17 rows x 21 columns]

# %%
df.drop_duplicates(subset=['Sub-Category','Category']).shape
# Out:
# (17, 21)

# %%
df.shape
# Out:
# (9994, 21)

# %%
categories=df.groupby('Category')
categories

# %%
len(df)
# Out:
# 9994

# %%
len(categories)
# Out:
# 3

# %%
categories.size()
# Out:
# Category
# Furniture          2121
# Office Supplies    6026
# Technology         1847
# dtype: int64
